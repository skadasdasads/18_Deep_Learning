# %%
pip install boto3
pip install matplotlib

# %%
import matplotlib.pyplot as plt 

img = plt.imread('./images/cat.png') 

plt.imshow(img)

# %%
import boto3
import base64

rekognition = boto3.client(
    'rekognition',
    region_name='ap-northeast-2'

)


# with : 파일이 열고 닫히는 것을 자동으로 관리해주는 역할
# => 파일작업중에 예외가 발생해도 안전하게 닫아준다.
# rb : binary모드로 읽겠다는 의미
with open ('./images/pikachu.jfif', 'rb') as cf:

    # AWS Rekognition으로 전송하기 위해 바이너리 데이터로 전처리
    base64_image = base64.b64encode(cf.read())
    base64_binary = base64.decodebytes(base64_image)
    print("file open!")

    response = rekognition.detect_labels(Image={'Bytes': base64_binary})

    response
# Out:
# file open!
# {'Labels': [{'Name': 'Plush',
#    'Confidence': 99.87019348144531,
#    'Instances': [],
#    'Parents': [{'Name': 'Toy'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Toys and Gaming'}]},
#   {'Name': 'Toy',
#    'Confidence': 99.87019348144531,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Hobbies and Interests'}]},
#   {'Name': 'Animal',
#    'Confidence': 75.6868896484375,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Animals and Pets'}]},
#   {'Name': 'Fish',
#    'Confidence': 75.6868896484375,
#    'Instances': [],
#    'Parents': [{'Name': 'Animal'}, {'Name': 'Sea Life'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Animals and Pets'}]},
#   {'Name': 'Sea Life',
#    'Confidence': 75.6868896484375,
#    'Instances': [],
#    'Parents': [{'Name': 'Animal'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Animals and Pets'}]},
#   {'Name': 'Shark',
#    'Confidence': 75.6868896484375,
#    'Instances': [{'BoundingBox': {'Width': 0.643638014793396,
#       'Height': 0.4692395031452179,
#       'Left': 0.2323143184185028,
#       'Top': 0.3472152650356293},
#      'Confidence': 75.6868896484375}],
#    'Parents': [{'Name': 'Animal'}, {'Name': 'Fish'}, {'Name': 'Sea Life'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Animals and Pets'}]},
#   {'Name': 'Pet',
#    'Confidence': 55.187679290771484,
#    'Instances': [],
#    'Parents': [{'Name': 'Animal'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Animals and Pets'}]}],
#  'LabelModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': 'c3ef7c29-c11d-470b-814a-3d13ac40cda7',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'c3ef7c29-c11d-470b-814a-3d13ac40cda7',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1252',
#    'date': 'Mon, 21 Oct 2024 05:46:31 GMT'},
#   'RetryAttempts': 0}}
